# %% [markdown]
# $\Large{\text{Ensemble methods - Part 2}}$
#
# $\large{\text{AdaBoost}}$

# %% [markdown]
# Let us first generate a synthetic data set.

# %% [markdown]
# We shall generate $n$ ($n$ being even) samples where the feature vector of each sample is 2-dimensional of the form $x^i = (x^i_1,x^i_2), i \in \{1,2,\ldots,n\}$. We assume that $\frac{n}{2}$ samples are from a spiral shaped data set called $S_1$ and other $\frac{n}{2}$ samples are from a different spiral called $S_2$. For each sample $x^i$ we have the following labeling scheme:
#
# $
# \begin{align}
# y^i = \begin{cases}
#         +1 \text{ if } x^i \in S_1 \\
#         -1 \text{ if }  x^i \in S_2.
#       \end{cases}
# \end{align}
# $
#
# Here the spirals $S_1$ and $S_2$ are associated with the parametric forms:
# $x_1 = r_1(\varphi) \cos \varphi$ and $x_2 = r_2(\varphi) \sin \varphi$ where$\varphi$ the angle and $r(\varphi)$ is a (monotonically increasing or decreasing) radius function depending on the angle $\varphi$. The coordinates are $x_1$ and $x_2$.

# %%
import numpy as np
from numpy import pi
import matplotlib.pyplot as plt
import random

num_samples = 200
angle = np.linspace(0,2*pi,int(num_samples/2))
mean = [0.0, 0.0]
cov = [ [6.0, 6.0], [6.0, 6.0] ]

X = np.zeros( (num_samples, 2) )

r_1 = 2*angle + pi
data_1 = np.array([np.cos(angle)*r_1, np.sin(angle)*r_1]).T
#print(data_1.shape)
X_1 = data_1 + np.random.multivariate_normal(mean, cov, int(num_samples/2)) #np.random.randn(int(num_samples/2),2)
X[:int(num_samples/2),:] = X_1

r_2 = -2*angle - pi
data_2 = np.array([np.cos(angle)*r_2, np.sin(angle)*r_2]).T
X_2 = data_2 + np.random.multivariate_normal(mean, cov, int(num_samples/2)) #np.random.randn(int(num_samples/2),2)
X[int(num_samples/2):,:] = X_2

y = np.ones(num_samples)
y[int(num_samples/2):] = -1*y[int(num_samples/2)]
#print(y)


print(X.shape)
print(y.shape)

figure, axes = plt.subplots(1)


plt.scatter(X[:int(num_samples/2),0],X[:int(num_samples/2),1], marker='o', color='red')
plt.scatter(X[int(num_samples/2):,0],X[int(num_samples/2):,1], marker='o', color='blue')


plt.title( 'Data from two spirals' )
plt.show()
# Out:
# (200, 2)
# (200,)

# %% [markdown]
# Consider an input space $\mathcal{X} \subseteq {\mathbb{R}}^d$ and the output space $\mathcal{Y} = \{+1,-1\}$. Assume a fixed (but unknown) distribution $P(X,Y)$ over $\mathcal{X} \times \mathcal{Y}$.
#
# Recall that we are given a training set $D=\{(x^i,y^i)\}_{i=1}^{N}$.
#
# We shall now discuss an iterative procedure called $\large{\text{AdaBoost}}$ to improve classification performance.
#
# 1. We start with $\omega^t_i = 1/N, \forall i \in \{1,2,\ldots,N\}$. (Note: $\omega^t_i$ is the weight associated with $i$-th training sample in round $t$.)
#
#
# 2. For round $t=1,2,\ldots,T$:
#
#   2.1. We train a classifier $h_t$ on the training set $D$ which minimizes the following error rate: $\epsilon_t = \sum_{i=1}^{n} \omega^t_i I(h_t(x^i)\neq y^i)$
#
# where $I(p)$ is the indicator function which takes value $1$ when $p$ is true and $0$ otherwise.
#
#   2.2. Compute: $\alpha_t = \frac{1}{2} \ln \frac{1-\epsilon_t}{\epsilon_t}$.
#
#   2.3. Update:  $\omega^{t+1}_i = \omega^t_{i}e^{-\alpha_t y^i h_t(x^i)}$, $\forall i \in \{1,2,\ldots,N\}$.
#
#   2.4. Normalize: $\omega^{t+1}_i = \omega^{t+1}_i/\sum_{j=1}^{N} \omega^{t+1}_j$.

# %% [markdown]
# $\textbf{Intuition behind weights $\omega$:}$ The weights $\omega$ have to be adjusted such that samples  which get misclassified are given large weights.

# %% [markdown]
# $\large{\text{Weight update procedure}}$
#
#
#
# *   Initially in round $1$, we start with uniform weights $\omega^j_1 = \frac{1}{n}, \ \forall j \in \{1,2,\ldots,n\}$.
# *   In round $i$, once we know the error rate $\epsilon_i$, we compute another parameter $\alpha_i = \frac{1}{2} \ln \left ( \frac{1-\epsilon_i}{\epsilon_i} \right )$.
# *   $\textbf{Question:}$ What is the behavior of $\alpha_i$ in relation to $\epsilon_i$? If $\epsilon_i$ is close to $1$, what value does $\alpha_i$ take?
# If $\epsilon_i$ is close to $0$, what value does $\alpha_i$ take?

# %% [markdown]
# $\large{\text{Final inference:}}$
#
# Suppose if we run $T$ rounds, then at the end of $T$-th round, for a test sample $\hat{x}$, predict $\hat{y} = \text{sign} \sum_{t=1}^{T} \alpha_t h_t(\hat{x})$.

# %% [markdown]
# $\textbf{A candidate for classifier $h_t$:}$
#
# Often $h_t$ is taken to be a very simple classifier of the form:
#
# $h_t(x) = s.\delta(x_k > c)$,
#
# where $c \in \mathbb{R}$, $s \in \{1,-1\}$ and $x_k$ denotes the $k$-th covariate of $x$. $\delta$ function gives $1$ when $x_k > c$ and $-1$ otherwise.
#
# The values of $s, k, c$ are often chosen by cross-validation.
#
# Here we will use all features to choose $h_t = \arg\min_h \sum_{i=1}^{n} \omega^t_i I(h(x^i)\neq y^i)$.

# %%
np.random.seed(1000)
#Create an index array
indexarr = np.arange(num_samples) #index array
np.random.shuffle(indexarr) #shuffle the indices
#print('shuffled indices of samples:')
#print(indexarr)

# %%
#Use the samples corresponding to first 80% of indexarr for training
num_train = int(0.8*num_samples)
#Use the remaining 20% samples for testing
num_test = num_samples-num_train
print('num_train: ',num_train, 'num_test: ', num_test)
# Out:
# num_train:  160 num_test:  40

# %%
#Use the first 80% of indexarr to create the train data features and train labels
train_X = X[indexarr[0:num_train]]
train_y = y[indexarr[0:num_train]]
print('shape of train data features:')
print(train_X.shape)
print('shape of train data labels')
print(train_y.shape)
# Out:
# shape of train data features:
# (160, 2)
# shape of train data labels
# (160,)

# %%
#Use remaining 20% of indexarr to create the test data and test labels
test_X = X[indexarr[num_train:num_samples]]
test_y = y[indexarr[num_train:num_samples]]
print('shape of test data features:')
print(test_X.shape)
print('shape of test data labels')
print(test_y.shape)
# Out:
# shape of test data features:
# (40, 2)
# shape of test data labels
# (40,)

# %%
def compute_predictions(X, dstumps):
  final_predictions = np.zeros(X.shape[0])
  for ds in dstumps:
    dim = ds['dim']
    thres = ds['stump_thresh']
    alpha = ds['alpha_t']
    sense = ds['sense']
    #print('inside inference:dim:',dim,'thres:',thres,'alpha:',alpha)
    if sense == 1:
      predictions = np.array([1 if X[i,dim] > thres else -1 for i in range(X.shape[0])])
    else:
      predictions = np.array([1 if X[i,dim] < thres else -1 for i in range(X.shape[0])])
    final_predictions = np.add(final_predictions, alpha*predictions)
  final_predictions = 2*(final_predictions >= 0) - 1
  #print(final_predictions)
  return final_predictions

# %%
from sklearn.metrics import accuracy_score

w_all_rounds = []
w = (1/num_train)*np.ones(num_train)
w_all_rounds.append(w)

y_pred = np.zeros(num_train)


alphas = []
decision_stumps = []

max_rounds = 100

sample_indices = np.arange(train_X.shape[0])
#print(sample_indices)
sample_indices_list = list(sample_indices)
#print(sample_indices_list)

for round in np.arange(1,max_rounds+1):
  best_dim = -99
  best_threshold = -99
  best_weighted_err_rate = 99.
  best_sense = -99
  best_predictions = []

  probs = tuple(w)#(0.5, 0.5)

  for dim in range(train_X.shape[1]): #pass through all dimensions
    #print('dimension:',dim)
    samples_feature = train_X[:, dim]
    #print('samples_feature:',samples_feature)
    sorted_idx = np.argsort(samples_feature)

    for feat in samples_feature[sorted_idx]:
      #create a decision stump
      #sense = 1
      predictions_gt = np.array([1 if train_X[i,dim] > feat else -1 for i in sample_indices_list])
      weighted_err_rate_gt = np.sum(np.array([0 if train_y[i] == predictions_gt[i] else w[i] for i in sample_indices_list])) #/train_X.shape[0] #division not required since w is already normalized

      #sense = -1
      predictions_lt = np.array([1 if train_X[i,dim] < feat else -1 for i in sample_indices_list])
      weighted_err_rate_lt = np.sum(np.array([0 if train_y[i] == predictions_lt[i] else w[i] for i in sample_indices_list])) #/train_X.shape[0]

      weighted_err_rate = min(weighted_err_rate_gt,weighted_err_rate_lt)
      #print('dim:%d threshold:%.6f weighted err rate:%.6f' %(dim, feat, weighted_err_rate))
      #print('predictions:',predictions)
      #print('***************************************')
      if best_weighted_err_rate > weighted_err_rate:
        best_weighted_err_rate = weighted_err_rate
        best_dim = dim
        best_threshold = feat
        if weighted_err_rate_gt>weighted_err_rate_lt:
          best_predictions = predictions_lt
          best_sense = -1
        else:
          best_predictions = predictions_gt
          best_sense = 1

    #print('#####################################')


  #compute alpha_t
  e_t = best_weighted_err_rate
  alpha_t = 0.5*np.log((1-e_t)/e_t)
  print('e_t:',e_t,'alpha_t:',alpha_t)

  #store the best decisionstump and weighted error rate
  decisionstump = dict()
  decisionstump['round'] = round
  decisionstump['e_t'] = e_t
  decisionstump['alpha_t'] = alpha_t
  decisionstump['dim'] = best_dim
  decisionstump['stump_thresh'] = best_threshold
  decisionstump['sense'] = best_sense

  decision_stumps.append(decisionstump)

  #update weights
  new_w = np.array([w[i]*np.exp(-alpha_t) if best_predictions[i]==train_y[i] else w[i]*np.exp(alpha_t) for i in range(train_X.shape[0])])

  #normalize weights
  w = new_w/np.sum(new_w)
  #print('w:',w)

  #store weights
  w_all_rounds.append(w)

  #compute train acc for decision stumps till current round
  y_pred = compute_predictions(train_X, decision_stumps)
  train_acc = accuracy_score(train_y, y_pred)
  print('round:',round,'train acc:',train_acc)
  print('--------------------------------------------------')

  #move on to next round
# Out:
# e_t: 0.36875 alpha_t: 0.26879153646777
# round: 1 train acc: 0.63125
# --------------------------------------------------
# e_t: 0.33235442188286624 alpha_t: 0.34877776287780915
# round: 2 train acc: 0.59375
# --------------------------------------------------
# e_t: 0.3866967733694333 alpha_t: 0.23060930957560344
# round: 3 train acc: 0.63125
# --------------------------------------------------
# e_t: 0.3727322260714969 alpha_t: 0.26025662592712184
# round: 4 train acc: 0.75
# --------------------------------------------------
# e_t: 0.41335755635306837 alpha_t: 0.17505126848982702
# round: 5 train acc: 0.63125
# --------------------------------------------------
# e_t: 0.3815802091611238 alpha_t: 0.2414232123071202
# round: 6 train acc: 0.7375
# --------------------------------------------------
# e_t: 0.4155927775899089 alpha_t: 0.17044607883721263
# round: 7 train acc: 0.76875
# --------------------------------------------------
# e_t: 0.4159592906116295 alpha_t: 0.16969164594472874
# round: 8 train acc: 0.7375
# --------------------------------------------------
# e_t: 0.3903179279236145 alpha_t: 0.222988010574283
# round: 9 train acc: 0.7375
# --------------------------------------------------
# e_t: 0.41414385022625166 alpha_t: 0.17343045172616295
# round: 10 train acc: 0.8375
# --------------------------------------------------
# e_t: 0.4159717593034362 alpha_t: 0.1696659836745547
# round: 11 train acc: 0.83125
# --------------------------------------------------
# e_t: 0.43842907302274703 alpha_t: 0.12377001676608972
# round: 12 train acc: 0.78125
# --------------------------------------------------
# e_t: 0.42937653535365333 alpha_t: 0.14219766096775607
# round: 13 train acc: 0.83125
# --------------------------------------------------
# e_t: 0.41042343657679264 alpha_t: 0.1811075956149016
# round: 14 train acc: 0.81875
# --------------------------------------------------
# e_t: 0.41083213024604326 alpha_t: 0.18026323113924242
# round: 15 train acc: 0.83125
# --------------------------------------------------
# e_t: 0.4328551092899979 alpha_t: 0.1351058794135494
# round: 16 train acc: 0.84375
# --------------------------------------------------
# e_t: 0.413229397202825 alpha_t: 0.17531553380074727
# round: 17 train acc: 0.8375
# --------------------------------------------------
# e_t: 0.4118698896585114 alpha_t: 0.17812035091887152
# round: 18 train acc: 0.84375
# --------------------------------------------------
# e_t: 0.41524007648978123 alpha_t: 0.1711722626533777
# round: 19 train acc: 0.8375
# --------------------------------------------------
# e_t: 0.4233098799342452 alpha_t: 0.15460029055563937
# round: 20 train acc: 0.8875
# --------------------------------------------------
# e_t: 0.44027307671925137 alpha_t: 0.12002693224386063
# round: 21 train acc: 0.825
# --------------------------------------------------
# e_t: 0.424555641108702 alpha_t: 0.15204973439579195
# round: 22 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.43317081013767833 alpha_t: 0.13446293749589766
# round: 23 train acc: 0.875
# --------------------------------------------------
# e_t: 0.44987719778824947 alpha_t: 0.10058343916721237
# round: 24 train acc: 0.86875
# --------------------------------------------------
# e_t: 0.4291057827125456 alpha_t: 0.14275023276038773
# round: 25 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.43192401101784017 alpha_t: 0.13700276042104642
# round: 26 train acc: 0.86875
# --------------------------------------------------
# e_t: 0.43255698238735046 alpha_t: 0.1357131329714621
# round: 27 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.43032827633526854 alpha_t: 0.14025596038368127
# round: 28 train acc: 0.8625
# --------------------------------------------------
# e_t: 0.44581871519779426 alpha_t: 0.1087897304406653
# round: 29 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4494887027425227 alpha_t: 0.10136837855519151
# round: 30 train acc: 0.8875
# --------------------------------------------------
# e_t: 0.43093483898763985 alpha_t: 0.1390190265071106
# round: 31 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.441647974751309 alpha_t: 0.11723825277459331
# round: 32 train acc: 0.875
# --------------------------------------------------
# e_t: 0.4392303161163157 alpha_t: 0.12214318099248664
# round: 33 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4251456982825518 alpha_t: 0.15084234535401284
# round: 34 train acc: 0.9125
# --------------------------------------------------
# e_t: 0.4404226811897262 alpha_t: 0.11972340301659729
# round: 35 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4362425790172167 alpha_t: 0.12821279590645443
# round: 36 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4379469738574436 alpha_t: 0.124749179607214
# round: 37 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.45231733744838853 alpha_t: 0.09565601439264415
# round: 38 train acc: 0.86875
# --------------------------------------------------
# e_t: 0.43639896331782707 alpha_t: 0.12789487049612566
# round: 39 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.4425502236197121 alpha_t: 0.11540922717649375
# round: 40 train acc: 0.8625
# --------------------------------------------------
# e_t: 0.4442552793068178 alpha_t: 0.11195485138406536
# round: 41 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.44620577808117673 alpha_t: 0.10800647285990961
# round: 42 train acc: 0.8625
# --------------------------------------------------
# e_t: 0.44859999480716667 alpha_t: 0.10316444874838727
# round: 43 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.44851626902067826 alpha_t: 0.10333369176984943
# round: 44 train acc: 0.85625
# --------------------------------------------------
# e_t: 0.4437445354629904 alpha_t: 0.11298931552737583
# round: 45 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4437437304765583 alpha_t: 0.11299094614201187
# round: 46 train acc: 0.85625
# --------------------------------------------------
# e_t: 0.44486568980936736 alpha_t: 0.11071883442822202
# round: 47 train acc: 0.9
# --------------------------------------------------
# e_t: 0.44451562695006885 alpha_t: 0.11142763339080888
# round: 48 train acc: 0.875
# --------------------------------------------------
# e_t: 0.4486956516932663 alpha_t: 0.1029710954493538
# round: 49 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.45656029663714637 alpha_t: 0.08709899154086262
# round: 50 train acc: 0.875
# --------------------------------------------------
# e_t: 0.44727610601030937 alpha_t: 0.10584124927400902
# round: 51 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.4482624776310826 alpha_t: 0.10384674090780124
# round: 52 train acc: 0.875
# --------------------------------------------------
# e_t: 0.44230509768994614 alpha_t: 0.11590606628701543
# round: 53 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.4497633742718219 alpha_t: 0.10081340239412048
# round: 54 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.4495153552801194 alpha_t: 0.1013145241553973
# round: 55 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4520264182440945 alpha_t: 0.09624322587219583
# round: 56 train acc: 0.875
# --------------------------------------------------
# e_t: 0.4441393745281154 alpha_t: 0.11218958472313512
# round: 57 train acc: 0.9
# --------------------------------------------------
# e_t: 0.45497585634436627 alpha_t: 0.09029286970196804
# round: 58 train acc: 0.875
# --------------------------------------------------
# e_t: 0.44487180863857706 alpha_t: 0.11070644615542097
# round: 59 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.45325082761272384 alpha_t: 0.09377223513775729
# round: 60 train acc: 0.875
# --------------------------------------------------
# e_t: 0.4564556521918324 alpha_t: 0.08730987603182483
# round: 61 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.45038597492728566 alpha_t: 0.09955566104108142
# round: 62 train acc: 0.875
# --------------------------------------------------
# e_t: 0.44995145057961594 alpha_t: 0.10043342833050059
# round: 63 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4520204528078649 alpha_t: 0.0962552676129984
# round: 64 train acc: 0.875
# --------------------------------------------------
# e_t: 0.45101770498199983 alpha_t: 0.09827979778961586
# round: 65 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4533187103657049 alpha_t: 0.09363527406395489
# round: 66 train acc: 0.875
# --------------------------------------------------
# e_t: 0.4466393441994495 alpha_t: 0.10712926835652525
# round: 67 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4533279311557711 alpha_t: 0.09361667035530018
# round: 68 train acc: 0.8875
# --------------------------------------------------
# e_t: 0.4555338711589003 alpha_t: 0.08916783006242306
# round: 69 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.45333622987241784 alpha_t: 0.09359992706148225
# round: 70 train acc: 0.88125
# --------------------------------------------------
# e_t: 0.4493495842491976 alpha_t: 0.10164949237604017
# round: 71 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4576149138282093 alpha_t: 0.08497410465495159
# round: 72 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.45311538920799976 alpha_t: 0.0940455078084182
# round: 73 train acc: 0.9
# --------------------------------------------------
# e_t: 0.45918540145400244 alpha_t: 0.08181123273796058
# round: 74 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4586179706976742 alpha_t: 0.08295381398182083
# round: 75 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.45646759356168587 alpha_t: 0.08728581082099754
# round: 76 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.45507153186385807 alpha_t: 0.09009995772040831
# round: 77 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4547293283349345 alpha_t: 0.09078997873759347
# round: 78 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.45259966561702986 alpha_t: 0.09508620653428447
# round: 79 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.44984088123922594 alpha_t: 0.10065681011759019
# round: 80 train acc: 0.9
# --------------------------------------------------
# e_t: 0.45580132758317166 alpha_t: 0.08862867869069309
# round: 81 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4573007764701024 alpha_t: 0.08560696085362948
# round: 82 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4579817493244679 alpha_t: 0.0842351695110701
# round: 83 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4578779824977092 alpha_t: 0.08444418289330805
# round: 84 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4547669205324021 alpha_t: 0.09071417342670446
# round: 85 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4560820140133697 alpha_t: 0.08806291290076244
# round: 86 train acc: 0.9
# --------------------------------------------------
# e_t: 0.4598290044561447 alpha_t: 0.08051552845785608
# round: 87 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.46305984453989546 alpha_t: 0.0740151731764966
# round: 88 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4588506786888943 alpha_t: 0.08248520610382062
# round: 89 train acc: 0.89375
# --------------------------------------------------
# e_t: 0.46354510545591093 alpha_t: 0.07303939491129888
# round: 90 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.459311392780303 alpha_t: 0.0815575650270746
# round: 91 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.46237334514137074 alpha_t: 0.07539584904194346
# round: 92 train acc: 0.9125
# --------------------------------------------------
# e_t: 0.4632592258606132 alpha_t: 0.07361423387854234
# round: 93 train acc: 0.9125
# --------------------------------------------------
# e_t: 0.451858845750187 alpha_t: 0.09658149581539946
# round: 94 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.45807442390382247 alpha_t: 0.08404850500806113
# round: 95 train acc: 0.9125
# --------------------------------------------------
# e_t: 0.45601599780688096 alpha_t: 0.08819597344073396
# round: 96 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4544631009855855 alpha_t: 0.09132686058510775
# round: 97 train acc: 0.91875
# --------------------------------------------------
# e_t: 0.4557545766254047 alpha_t: 0.08872291777818526
# round: 98 train acc: 0.90625
# --------------------------------------------------
# e_t: 0.4532438778828861 alpha_t: 0.09378625719565181
# round: 99 train acc: 0.91875
# --------------------------------------------------
# e_t: 0.45467205623079343 alpha_t: 0.09090547091842877
# round: 100 train acc: 0.90625
# --------------------------------------------------

# %%
import seaborn as sns
ax = sns.heatmap(w_all_rounds)

# %%
y_pred = compute_predictions(test_X, decision_stumps)
test_acc = accuracy_score(test_y, y_pred)
print('test acc:',test_acc)
# Out:
# test acc: 0.85

# %%
# create a mesh to plot in
h=0.02 #mesh step size
x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, h),
                     np.arange(x2_min, x2_max, h))

testX = np.c_[xx1.ravel(), xx2.ravel()]
#print(testX.shape)
Z = compute_predictions(testX, decision_stumps)

# Put the result into a color plot
Z = Z.reshape(xx1.shape)
plt.contourf(xx1, xx2, Z, cmap=plt.cm.coolwarm, alpha=0.8)

# Plot also the training points
#plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)

idx_p = np.where(train_y == 1)
idx_n = np.where(train_y == -1)

plt.scatter(train_X[idx_p,0],train_X[idx_p,1], marker='o', color='red')
plt.scatter(train_X[idx_n,0],train_X[idx_n,1], marker='s', color='blue')

plt.xlabel('x1')
plt.ylabel('x2')
plt.xlim(xx1.min(), xx1.max())
plt.ylim(xx2.min(), xx2.max())
plt.xticks(())
plt.yticks(())
plt.title('Decision boundary from AdaBoost')
plt.show()

# %% [markdown]
# $\large{\text{Exercise Problems}}$
#
# 1. (a) Consider the above data set creation procedure with only 100 samples (with 50 samples from each class). Try the adaboost algorithm on 80\% train split obtained from this data set and compute performance on the test set obtained from remaining 20\% of the samples. Write your observations.
#
#  (b) Consider the above data set creation procedure with only 50 samples (with 25 samples from each class). Try the adaboost algorithm on 80\% train split obtained from this data set and compute performance on the test set obtained from remaining 20\% of the samples. Write your observations.
#
#  (c) Consider the above data set creation procedure with 600 samples (with 300 samples from each class). Try the adaboost algorithm on 80\% train split obtained from this data set and compute performance on the test set obtained from remaining 20\% of the samples. Write your observations.
#
#  (d) Compare and contrast the different test set performances.
#
# 2. Consider the above data set creation procedure with 200 samples, consider 80\% as train split and remaining 20\% as test split.  Choose the number of rounds from the set $\{10,25,50,100,150,200,250,300,350,400,450,500,550,600,650,700\}$ and plot the train set and test set performance. Explain your observations.
# 3. Devise a strategy to control the behavior of overfitting which might be observed in adaboost. Implement your strategy and check the performance on train and test sets.
